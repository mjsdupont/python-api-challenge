# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 10
#       7 from scipy.stats import linregress
#       9 # Impor the OpenWeatherMap API key
# ---> 10 from api_keys import weather_api_key
#      12 # Import citipy to determine the cities based on latitude and longitude
#      13 from citipy import citipy
#
# ModuleNotFoundError: No module named 'api_keys'

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 565

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = 'metric'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']


        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | haiku-pauwela
# Processing Record 3 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 4 of Set 1 | chul'man
# Processing Record 5 of Set 1 | sisimiut
# Processing Record 6 of Set 1 | olonkinbyen
# Processing Record 7 of Set 1 | papatowai
# Processing Record 8 of Set 1 | keflavik
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 13 of Set 1 | korem
# Processing Record 14 of Set 1 | elverum
# Processing Record 15 of Set 1 | enewetak
# Processing Record 16 of Set 1 | edinburgh of the seven seas
# Processing Record 17 of Set 1 | manokwari
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | blackmans bay
# Processing Record 20 of Set 1 | ginir
# Processing Record 21 of Set 1 | weno
# Processing Record 22 of Set 1 | touros
# Processing Record 23 of Set 1 | ulladulla
# Processing Record 24 of Set 1 | tabou
# Processing Record 25 of Set 1 | san javier
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | waitangi
# Processing Record 28 of Set 1 | adamstown
# Processing Record 29 of Set 1 | karratha
# Processing Record 30 of Set 1 | college
# Processing Record 31 of Set 1 | punta alta
# Processing Record 32 of Set 1 | whitehorse
# Processing Record 33 of Set 1 | dakhla
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | hamilton
# Processing Record 36 of Set 1 | katsuura
# Processing Record 37 of Set 1 | susuman
# Processing Record 38 of Set 1 | vila velha
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | kourou
# Processing Record 41 of Set 1 | grytviken
# Processing Record 42 of Set 1 | moyale
# Processing Record 43 of Set 1 | yacimiento rio turbio
# Processing Record 44 of Set 1 | bilibino
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | elmendorf air force base
# City not found. Skipping...
# Processing Record 48 of Set 1 | hue
# Processing Record 49 of Set 1 | glace bay
# Processing Record 50 of Set 1 | kununurra
# Processing Record 0 of Set 2 | erdenet
# Processing Record 1 of Set 2 | calama
# Processing Record 2 of Set 2 | adrar
# Processing Record 3 of Set 2 | qaqortoq
# Processing Record 4 of Set 2 | malango
# Processing Record 5 of Set 2 | mareeba
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | sungai raya
# Processing Record 8 of Set 2 | vorgashor
# Processing Record 9 of Set 2 | antigonish
# Processing Record 10 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 11 of Set 2 | klyuchi
# Processing Record 12 of Set 2 | howrah
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | port mathurin
# Processing Record 15 of Set 2 | salinas
# Processing Record 16 of Set 2 | cannonvale
# Processing Record 17 of Set 2 | uturoa
# Processing Record 18 of Set 2 | tafuna
# Processing Record 19 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 20 of Set 2 | quellon
# Processing Record 21 of Set 2 | maintirano
# Processing Record 22 of Set 2 | mahina
# Processing Record 23 of Set 2 | kataragama
# City not found. Skipping...
# Processing Record 24 of Set 2 | happy valley-goose bay
# Processing Record 25 of Set 2 | choyr
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | flying fish cove
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | saratamata
# City not found. Skipping...
# Processing Record 30 of Set 2 | maun
# Processing Record 31 of Set 2 | littlefield
# Processing Record 32 of Set 2 | poronaysk
# Processing Record 33 of Set 2 | makokou
# Processing Record 34 of Set 2 | vatutine
# Processing Record 35 of Set 2 | egilsstadir
# Processing Record 36 of Set 2 | punta arenas
# Processing Record 37 of Set 2 | chui
# Processing Record 38 of Set 2 | menaka
# Processing Record 39 of Set 2 | wailua homesteads
# Processing Record 40 of Set 2 | point pedro
# Processing Record 41 of Set 2 | aasiaat
# Processing Record 42 of Set 2 | tamanrasset
# Processing Record 43 of Set 2 | margaret river
# Processing Record 44 of Set 2 | pisco
# Processing Record 45 of Set 2 | isafjordur
# Processing Record 46 of Set 2 | hawaiian paradise park
# Processing Record 47 of Set 2 | ahau
# City not found. Skipping...
# Processing Record 48 of Set 2 | puerto deseado
# Processing Record 49 of Set 2 | northam
# Processing Record 0 of Set 3 | hithadhoo
# Processing Record 1 of Set 3 | remire-montjoly
# Processing Record 2 of Set 3 | mil'kovo
# Processing Record 3 of Set 3 | bikenibeu village
# Processing Record 4 of Set 3 | veinticinco de mayo
# Processing Record 5 of Set 3 | maluso
# Processing Record 6 of Set 3 | mount isa
# Processing Record 7 of Set 3 | kumagunnam
# Processing Record 8 of Set 3 | tiksi
# Processing Record 9 of Set 3 | la ferte-saint-aubin
# Processing Record 10 of Set 3 | guanica
# Processing Record 11 of Set 3 | burang
# Processing Record 12 of Set 3 | puerto natales
# Processing Record 13 of Set 3 | san antonio de pale
# Processing Record 14 of Set 3 | kotabumi
# Processing Record 15 of Set 3 | saldanha
# Processing Record 16 of Set 3 | palikir - national government center
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | ilhabela
# Processing Record 19 of Set 3 | alice springs
# Processing Record 20 of Set 3 | labinsk
# Processing Record 21 of Set 3 | sitka
# Processing Record 22 of Set 3 | ciudad lazaro cardenas
# Processing Record 23 of Set 3 | west island
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | ilulissat
# Processing Record 26 of Set 3 | zindah jan
# Processing Record 27 of Set 3 | tazacorte
# Processing Record 28 of Set 3 | igrim
# Processing Record 29 of Set 3 | sinabang
# Processing Record 30 of Set 3 | puerto san jose
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | antofagasta
# Processing Record 33 of Set 3 | fale old settlement
# Processing Record 34 of Set 3 | rocky mountain house
# Processing Record 35 of Set 3 | laguna
# Processing Record 36 of Set 3 | barcelos
# Processing Record 37 of Set 3 | brisas de zicatela
# Processing Record 38 of Set 3 | airali
# Processing Record 39 of Set 3 | hadibu
# Processing Record 40 of Set 3 | arthur's town
# City not found. Skipping...
# Processing Record 41 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 42 of Set 3 | kanevskaya
# Processing Record 43 of Set 3 | sonsorol village
# City not found. Skipping...
# Processing Record 44 of Set 3 | nadi
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | okhotsk
# Processing Record 47 of Set 3 | lakhdenpokh'ya
# Processing Record 48 of Set 3 | tawau
# Processing Record 49 of Set 3 | invercargill
# Processing Record 0 of Set 4 | cabo san lucas
# Processing Record 1 of Set 4 | loudi
# Processing Record 2 of Set 4 | el abiodh sidi cheikh
# Processing Record 3 of Set 4 | mount darwin
# Processing Record 4 of Set 4 | saksaul'skiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | fort bragg
# Processing Record 6 of Set 4 | dzhalagash
# Processing Record 7 of Set 4 | vernon
# Processing Record 8 of Set 4 | paragominas
# Processing Record 9 of Set 4 | black point
# Processing Record 10 of Set 4 | gornozavodsk
# Processing Record 11 of Set 4 | hasaki
# Processing Record 12 of Set 4 | horta
# Processing Record 13 of Set 4 | espargos
# City not found. Skipping...
# Processing Record 14 of Set 4 | ust-nera
# Processing Record 15 of Set 4 | itaituba
# Processing Record 16 of Set 4 | rio grande
# Processing Record 17 of Set 4 | visby
# Processing Record 18 of Set 4 | kodiak
# Processing Record 19 of Set 4 | nova vicosa
# Processing Record 20 of Set 4 | pontianak
# Processing Record 21 of Set 4 | lihue
# Processing Record 22 of Set 4 | camacupa
# Processing Record 23 of Set 4 | codrington
# Processing Record 24 of Set 4 | alofi
# Processing Record 25 of Set 4 | severo-yeniseyskiy
# Processing Record 26 of Set 4 | monte maiz
# Processing Record 27 of Set 4 | nuuk
# Processing Record 28 of Set 4 | constantia
# Processing Record 29 of Set 4 | kingston
# Processing Record 30 of Set 4 | utrik
# Processing Record 31 of Set 4 | afaahiti
# Processing Record 32 of Set 4 | hastings
# Processing Record 33 of Set 4 | trinidad
# Processing Record 34 of Set 4 | lospalos
# Processing Record 35 of Set 4 | puerto baquerizo moreno
# Processing Record 36 of Set 4 | khandyga
# Processing Record 37 of Set 4 | xining
# Processing Record 38 of Set 4 | nova sintra
# Processing Record 39 of Set 4 | ljusdal
# Processing Record 40 of Set 4 | mmabatho
# Processing Record 41 of Set 4 | yorkton
# Processing Record 42 of Set 4 | nemuro
# Processing Record 43 of Set 4 | prey veng
# Processing Record 44 of Set 4 | queenstown
# Processing Record 45 of Set 4 | saipan
# Processing Record 46 of Set 4 | costa rica
# Processing Record 47 of Set 4 | ispir
# Processing Record 48 of Set 4 | stanley
# Processing Record 49 of Set 4 | skelleftea
# Processing Record 0 of Set 5 | mandalgovi
# Processing Record 1 of Set 5 | tazovsky
# Processing Record 2 of Set 5 | villa gesell
# Processing Record 3 of Set 5 | pandan
# Processing Record 4 of Set 5 | tura
# Processing Record 5 of Set 5 | chonchi
# Processing Record 6 of Set 5 | hami
# Processing Record 7 of Set 5 | thunder bay
# Processing Record 8 of Set 5 | bayindir
# Processing Record 9 of Set 5 | anadyr
# Processing Record 10 of Set 5 | orlovskiy
# Processing Record 11 of Set 5 | balsas
# Processing Record 12 of Set 5 | madimba
# Processing Record 13 of Set 5 | novovyazniki
# Processing Record 14 of Set 5 | iskateley
# Processing Record 15 of Set 5 | bardai
# Processing Record 16 of Set 5 | nogales
# Processing Record 17 of Set 5 | kittila
# Processing Record 18 of Set 5 | prado
# Processing Record 19 of Set 5 | falenki
# Processing Record 20 of Set 5 | anacapri
# Processing Record 21 of Set 5 | la trinite
# Processing Record 22 of Set 5 | mugia
# Processing Record 23 of Set 5 | hammerfest
# Processing Record 24 of Set 5 | san jose
# Processing Record 25 of Set 5 | udachny
# Processing Record 26 of Set 5 | turmalina
# Processing Record 27 of Set 5 | bandarbeyla
# Processing Record 28 of Set 5 | lillesand
# Processing Record 29 of Set 5 | tobelo
# Processing Record 30 of Set 5 | cidreira
# Processing Record 31 of Set 5 | murzuq
# Processing Record 32 of Set 5 | nagqu
# Processing Record 33 of Set 5 | as sulayyil
# Processing Record 34 of Set 5 | port glaud
# City not found. Skipping...
# Processing Record 35 of Set 5 | ouro sogui
# Processing Record 36 of Set 5 | kapuskasing
# Processing Record 37 of Set 5 | nyurba
# Processing Record 38 of Set 5 | mana
# Processing Record 39 of Set 5 | irituia
# Processing Record 40 of Set 5 | naberera
# Processing Record 41 of Set 5 | oyama
# Processing Record 42 of Set 5 | nadym
# Processing Record 43 of Set 5 | port alfred
# Processing Record 44 of Set 5 | yallahs
# Processing Record 45 of Set 5 | inirida
# Processing Record 46 of Set 5 | cockburn town
# Processing Record 47 of Set 5 | zimmerman
# Processing Record 48 of Set 5 | vadso
# Processing Record 49 of Set 5 | deltebre
# Processing Record 0 of Set 6 | batesville
# Processing Record 1 of Set 6 | sandnessjoen
# Processing Record 2 of Set 6 | nar'yan-mar
# Processing Record 3 of Set 6 | rudnyy
# Processing Record 4 of Set 6 | luau
# Processing Record 5 of Set 6 | la ronge
# Processing Record 6 of Set 6 | verkhnevilyuysk
# Processing Record 7 of Set 6 | mokolo
# Processing Record 8 of Set 6 | callao
# Processing Record 9 of Set 6 | salekhard
# Processing Record 10 of Set 6 | roquetas de mar
# Processing Record 11 of Set 6 | metahara
# Processing Record 12 of Set 6 | shubarkuduk
# Processing Record 13 of Set 6 | tucuma
# Processing Record 14 of Set 6 | villamontes
# Processing Record 15 of Set 6 | savave village
# City not found. Skipping...
# Processing Record 16 of Set 6 | east london
# Processing Record 17 of Set 6 | shahdadpur
# Processing Record 18 of Set 6 | kananga
# Processing Record 19 of Set 6 | batangafo
# Processing Record 20 of Set 6 | negru voda
# Processing Record 21 of Set 6 | shakawe
# Processing Record 22 of Set 6 | magadan
# Processing Record 23 of Set 6 | corte
# Processing Record 24 of Set 6 | geraldton
# Processing Record 25 of Set 6 | vila franca do campo
# Processing Record 26 of Set 6 | ugoofaaru
# Processing Record 27 of Set 6 | bignona
# Processing Record 28 of Set 6 | chivilcoy
# Processing Record 29 of Set 6 | mayen abun
# City not found. Skipping...
# Processing Record 30 of Set 6 | bucerias
# Processing Record 31 of Set 6 | sovetskiy
# Processing Record 32 of Set 6 | abadeh
# Processing Record 33 of Set 6 | kamina
# Processing Record 34 of Set 6 | rongelap
# Processing Record 35 of Set 6 | awjilah
# Processing Record 36 of Set 6 | bu'aale
# Processing Record 37 of Set 6 | mejit
# Processing Record 38 of Set 6 | coruripe
# Processing Record 39 of Set 6 | badger
# Processing Record 40 of Set 6 | kismayo
# Processing Record 41 of Set 6 | cassilandia
# Processing Record 42 of Set 6 | georgetown
# Processing Record 43 of Set 6 | obergunzburg
# Processing Record 44 of Set 6 | ghanzi
# Processing Record 45 of Set 6 | kirensk
# Processing Record 46 of Set 6 | sawang daen din
# Processing Record 47 of Set 6 | taltal
# Processing Record 48 of Set 6 | gazojak
# Processing Record 49 of Set 6 | broken hill
# Processing Record 0 of Set 7 | nizhneudinsk
# Processing Record 1 of Set 7 | at taj
# Processing Record 2 of Set 7 | holtville
# Processing Record 3 of Set 7 | kruisfontein
# Processing Record 4 of Set 7 | tabalah
# Processing Record 5 of Set 7 | al bawiti
# Processing Record 6 of Set 7 | fuling
# Processing Record 7 of Set 7 | fort frances
# Processing Record 8 of Set 7 | minas de marcona
# Processing Record 9 of Set 7 | tsiombe
# Processing Record 10 of Set 7 | whakatane
# Processing Record 11 of Set 7 | maceio
# Processing Record 12 of Set 7 | fiambala
# Processing Record 13 of Set 7 | aykhal
# Processing Record 14 of Set 7 | portland
# Processing Record 15 of Set 7 | saint-joseph
# Processing Record 16 of Set 7 | saurimo
# Processing Record 17 of Set 7 | sheridan
# Processing Record 18 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 19 of Set 7 | asyut
# Processing Record 20 of Set 7 | puerto ayacucho
# Processing Record 21 of Set 7 | ouadda
# Processing Record 22 of Set 7 | javea
# Processing Record 23 of Set 7 | isiolo
# Processing Record 24 of Set 7 | mariel
# Processing Record 25 of Set 7 | muynoq
# Processing Record 26 of Set 7 | ebaye
# Processing Record 27 of Set 7 | binzhou
# Processing Record 28 of Set 7 | vilyuchinsk
# Processing Record 29 of Set 7 | manismata
# Processing Record 30 of Set 7 | caleta de carquin
# Processing Record 31 of Set 7 | zapolyarnyy
# Processing Record 32 of Set 7 | heber springs
# Processing Record 33 of Set 7 | newman
# Processing Record 34 of Set 7 | mahibadhoo
# Processing Record 35 of Set 7 | mata-utu
# Processing Record 36 of Set 7 | berber
# Processing Record 37 of Set 7 | ancud
# Processing Record 38 of Set 7 | tolanaro
# Processing Record 39 of Set 7 | kigoma
# Processing Record 40 of Set 7 | undurkhaan
# Processing Record 41 of Set 7 | labrador city
# Processing Record 42 of Set 7 | myitkyina
# Processing Record 43 of Set 7 | bargara
# City not found. Skipping...
# Processing Record 44 of Set 7 | caririacu
# Processing Record 45 of Set 7 | kujang-up
# Processing Record 46 of Set 7 | atafu village
# Processing Record 47 of Set 7 | mount gambier
# Processing Record 48 of Set 7 | likasi
# Processing Record 49 of Set 7 | champerico
# Processing Record 0 of Set 8 | selfoss
# Processing Record 1 of Set 8 | richards bay
# Processing Record 2 of Set 8 | filadelfia
# Processing Record 3 of Set 8 | sola
# Processing Record 4 of Set 8 | tual
# Processing Record 5 of Set 8 | zaozersk
# Processing Record 6 of Set 8 | amboasary
# Processing Record 7 of Set 8 | prince rupert
# Processing Record 8 of Set 8 | longyearbyen
# Processing Record 9 of Set 8 | uaboe
# City not found. Skipping...
# Processing Record 10 of Set 8 | kavieng
# Processing Record 11 of Set 8 | umea
# Processing Record 12 of Set 8 | punta del este
# Processing Record 13 of Set 8 | al-`ula
# City not found. Skipping...
# Processing Record 14 of Set 8 | nkurenkuru
# City not found. Skipping...
# Processing Record 15 of Set 8 | retreat
# Processing Record 16 of Set 8 | kerikeri
# Processing Record 17 of Set 8 | mukalla
# Processing Record 18 of Set 8 | doka
# Processing Record 19 of Set 8 | port douglas
# Processing Record 20 of Set 8 | guelmim
# Processing Record 21 of Set 8 | belle fourche
# Processing Record 22 of Set 8 | escanaba
# Processing Record 23 of Set 8 | chipinge
# Processing Record 24 of Set 8 | lazaro cardenas
# Processing Record 25 of Set 8 | namibe
# Processing Record 26 of Set 8 | kalabo
# Processing Record 27 of Set 8 | badarwas
# Processing Record 28 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 29 of Set 8 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 30 of Set 8 | bull savanna
# Processing Record 31 of Set 8 | ihosy
# Processing Record 32 of Set 8 | dubrovnik
# Processing Record 33 of Set 8 | basco
# Processing Record 34 of Set 8 | kaifeng
# Processing Record 35 of Set 8 | marudi
# City not found. Skipping...
# Processing Record 36 of Set 8 | samitah
# Processing Record 37 of Set 8 | hinton
# Processing Record 38 of Set 8 | coquimbo
# Processing Record 39 of Set 8 | abra pampa
# Processing Record 40 of Set 8 | lodja
# Processing Record 41 of Set 8 | jumla
# Processing Record 42 of Set 8 | kaka
# Processing Record 43 of Set 8 | kenai
# Processing Record 44 of Set 8 | tindouf
# Processing Record 45 of Set 8 | praia da vitoria
# Processing Record 46 of Set 8 | hualien city
# Processing Record 47 of Set 8 | gadzhiyevo
# Processing Record 48 of Set 8 | st. john's
# Processing Record 49 of Set 8 | san carlos centro
# Processing Record 0 of Set 9 | margate
# Processing Record 1 of Set 9 | talara
# Processing Record 2 of Set 9 | nuevo progreso
# Processing Record 3 of Set 9 | new norfolk
# Processing Record 4 of Set 9 | karditsa
# Processing Record 5 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 6 of Set 9 | camana
# Processing Record 7 of Set 9 | usinsk
# Processing Record 8 of Set 9 | hajjah
# Processing Record 9 of Set 9 | sittwe
# Processing Record 10 of Set 9 | mount pearl
# Processing Record 11 of Set 9 | inari
# Processing Record 12 of Set 9 | velizh
# Processing Record 13 of Set 9 | sarmiento
# Processing Record 14 of Set 9 | taroa
# Processing Record 15 of Set 9 | vila do maio
# Processing Record 16 of Set 9 | port blair
# Processing Record 17 of Set 9 | rengo
# Processing Record 18 of Set 9 | general villegas
# Processing Record 19 of Set 9 | al jaradiyah
# Processing Record 20 of Set 9 | murrells inlet
# Processing Record 21 of Set 9 | nurlat
# Processing Record 22 of Set 9 | qarauyl
# Processing Record 23 of Set 9 | mankoeng
# Processing Record 24 of Set 9 | san justo
# Processing Record 25 of Set 9 | as salamiyah
# Processing Record 26 of Set 9 | mirto
# Processing Record 27 of Set 9 | port shepstone
# Processing Record 28 of Set 9 | daira din panah
# Processing Record 29 of Set 9 | peniche
# Processing Record 30 of Set 9 | dudinka
# Processing Record 31 of Set 9 | sausset-les-pins
# Processing Record 32 of Set 9 | mstsislaw
# Processing Record 33 of Set 9 | acapulco de juarez
# Processing Record 34 of Set 9 | kupang
# Processing Record 35 of Set 9 | lahore
# Processing Record 36 of Set 9 | cestos city
# Processing Record 37 of Set 9 | bhadra
# Processing Record 38 of Set 9 | tome
# Processing Record 39 of Set 9 | dauphin
# Processing Record 40 of Set 9 | nema
# Processing Record 41 of Set 9 | pointe-noire
# Processing Record 42 of Set 9 | bullsbrook
# Processing Record 43 of Set 9 | puerto carreno
# Processing Record 44 of Set 9 | dongola
# Processing Record 45 of Set 9 | waddan
# Processing Record 46 of Set 9 | mont-dore
# Processing Record 47 of Set 9 | colonia
# Processing Record 48 of Set 9 | gulf shores
# Processing Record 49 of Set 9 | quiberon
# Processing Record 0 of Set 10 | waterloo
# Processing Record 1 of Set 10 | grand falls-windsor
# Processing Record 2 of Set 10 | antsiranana
# Processing Record 3 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 4 of Set 10 | beledweyne
# Processing Record 5 of Set 10 | perth
# Processing Record 6 of Set 10 | kachkanar
# Processing Record 7 of Set 10 | dogondoutchi
# Processing Record 8 of Set 10 | ribeira brava
# Processing Record 9 of Set 10 | mbandaka
# Processing Record 10 of Set 10 | rouyn-noranda
# Processing Record 11 of Set 10 | polyarnyy
# Processing Record 12 of Set 10 | carutapera
# Processing Record 13 of Set 10 | olgii
# City not found. Skipping...
# Processing Record 14 of Set 10 | bamboo flat
# Processing Record 15 of Set 10 | ouellah
# City not found. Skipping...
# Processing Record 16 of Set 10 | strezhevoy
# Processing Record 17 of Set 10 | ruteng
# Processing Record 18 of Set 10 | puerto real
# Processing Record 19 of Set 10 | tuy hoa
# Processing Record 20 of Set 10 | madalena
# Processing Record 21 of Set 10 | xilin hot
# Processing Record 22 of Set 10 | yumbe
# Processing Record 23 of Set 10 | la'ie
# Processing Record 24 of Set 10 | al wakrah
# Processing Record 25 of Set 10 | sant pol de mar
# Processing Record 26 of Set 10 | jiangyou
# Processing Record 27 of Set 10 | fauske
# Processing Record 28 of Set 10 | markaz-e hukumat-e darweshan
# Processing Record 29 of Set 10 | la serena
# Processing Record 30 of Set 10 | salinopolis
# Processing Record 31 of Set 10 | port lincoln
# Processing Record 32 of Set 10 | zouerate
# Processing Record 33 of Set 10 | paradip garh
# Processing Record 34 of Set 10 | itoman
# Processing Record 35 of Set 10 | fort mcmurray
# Processing Record 36 of Set 10 | tuscaloosa
# Processing Record 37 of Set 10 | manaure
# Processing Record 38 of Set 10 | maya
# Processing Record 39 of Set 10 | tobi village
# City not found. Skipping...
# Processing Record 40 of Set 10 | khark
# Processing Record 41 of Set 10 | nassau
# Processing Record 42 of Set 10 | puerto aysen
# Processing Record 43 of Set 10 | tripoli
# Processing Record 44 of Set 10 | burela de cabo
# Processing Record 45 of Set 10 | bafoulabe
# Processing Record 46 of Set 10 | anabar
# City not found. Skipping...
# Processing Record 47 of Set 10 | penticton
# Processing Record 48 of Set 10 | thinadhoo
# Processing Record 49 of Set 10 | monsanto
# Processing Record 0 of Set 11 | baloda bazar
# Processing Record 1 of Set 11 | tinambac
# Processing Record 2 of Set 11 | kale
# Processing Record 3 of Set 11 | plymouth
# Processing Record 4 of Set 11 | oamaru
# Processing Record 5 of Set 11 | namdrik
# Processing Record 6 of Set 11 | ylitornio
# Processing Record 7 of Set 11 | inhambane
# Processing Record 8 of Set 11 | bushland beach
# City not found. Skipping...
# Processing Record 9 of Set 11 | kiunga
# Processing Record 10 of Set 11 | miasskoye
# Processing Record 11 of Set 11 | nuku'alofa
# Processing Record 12 of Set 11 | campbell river
# Processing Record 13 of Set 11 | juye
# Processing Record 14 of Set 11 | gorom-gorom
# Processing Record 15 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 16 of Set 11 | lembar
# City not found. Skipping...
# Processing Record 17 of Set 11 | auki
# Processing Record 18 of Set 11 | lusambo
# Processing Record 19 of Set 11 | luce
# Processing Record 20 of Set 11 | abepura
# Processing Record 21 of Set 11 | karasburg
# Processing Record 22 of Set 11 | isla mujeres
# Processing Record 23 of Set 11 | coxen hole
# Processing Record 24 of Set 11 | kosh-agach
# Processing Record 25 of Set 11 | kailua-kona
# Processing Record 26 of Set 11 | zhosaly
# Processing Record 27 of Set 11 | castillos
# Processing Record 28 of Set 11 | great bend
# Processing Record 29 of Set 11 | san fernando
# Processing Record 30 of Set 11 | yangor
# City not found. Skipping...
# Processing Record 31 of Set 11 | micheweni
# Processing Record 32 of Set 11 | barysh
# Processing Record 33 of Set 11 | jinghong
# Processing Record 34 of Set 11 | kropachevo
# Processing Record 35 of Set 11 | bam
# Processing Record 36 of Set 11 | santarem
# Processing Record 37 of Set 11 | harper
# Processing Record 38 of Set 11 | sao paulo de olivenca
# Processing Record 39 of Set 11 | igarka
# Processing Record 40 of Set 11 | independence
# Processing Record 41 of Set 11 | crane
# Processing Record 42 of Set 11 | alenquer
# Processing Record 43 of Set 11 | belomorsk
# Processing Record 44 of Set 11 | kuala terengganu
# Processing Record 45 of Set 11 | mili
# Processing Record 46 of Set 11 | katsuren-haebaru
# Processing Record 47 of Set 11 | ialibu
# Processing Record 48 of Set 11 | coyhaique
# Processing Record 49 of Set 11 | luderitz
# Processing Record 0 of Set 12 | la passe
# Processing Record 1 of Set 12 | cam ranh
# Processing Record 2 of Set 12 | leua
# Processing Record 3 of Set 12 | bartoszyce
# Processing Record 4 of Set 12 | pitea
# Processing Record 5 of Set 12 | aripuana
# Processing Record 6 of Set 12 | tottori
# Processing Record 7 of Set 12 | conception bay south
# Processing Record 8 of Set 12 | north manchester
# Processing Record 9 of Set 12 | beauvais
# Processing Record 10 of Set 12 | kitimat
# Processing Record 11 of Set 12 | longquan
# Processing Record 12 of Set 12 | princeville
# Processing Record 13 of Set 12 | ierapetra
# Processing Record 14 of Set 12 | piacabucu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          532
# Lat           532
# Lng           532
# Max Temp      532
# Humidity      532
# Cloudiness    532
# Wind Speed    532
# Country       532
# Date          532
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     bredasdorp -34.5322   20.0403     33.04        30           0
# 1  haiku-pauwela  20.9219 -156.3051     20.02        76           0
# 2       chul'man  56.8479  124.9104    -15.74        98         100
# 3       sisimiut  66.9395  -53.6735    -22.85        84          28
# 4    olonkinbyen  70.9221   -8.7187     -2.04        88         100
#
#    Wind Speed Country        Date
# 0        5.85      ZA  1707744438
# 1        2.57      US  1707744439
# 2        0.56      RU  1707744440
# 3        3.19      GL  1707744441
# 4        8.10      SJ  1707744441

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           bredasdorp -34.5322   20.0403     33.04        30           0
# 1        haiku-pauwela  20.9219 -156.3051     20.02        76           0
# 2             chul'man  56.8479  124.9104    -15.74        98         100
# 3             sisimiut  66.9395  -53.6735    -22.85        84          28
# 4          olonkinbyen  70.9221   -8.7187     -2.04        88         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.85      ZA  1707744438
# 1              2.57      US  1707744439
# 2              0.56      RU  1707744440
# 3              3.19      GL  1707744441
# 4              8.10      SJ  1707744441

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# # Build scatter plot for latitude vs. temperature
import datetime
import matplotlib.pyplot as plt


plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], alpha=0.5, edgecolors='black')

# Format date
date = datetime.datetime.now()
date_str = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)
plt.title(f"City Max Latitude vs. Temperature ({date_str})")  
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], alpha = 0.5, edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Humidity ({date_str})") 
plt.xlabel("Latitude")
plt.ylabel('Humidity (%)')
plt.grid(True)


# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df ['Lat'], city_data_df['Cloudiness'], alpha = 0.5, edgecolors ='black')

# Incorporate the other graph properties

plt.title(f"City Max Latitude vs. Cloudiness ({date_str})") 
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid("Ture")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], alpha = 0.5, edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. WindSpeed ({date_str})") 
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (%)')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(x, y, xlabel='', ylabel='', title=''):
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.text(0.5, 0.9, line_eq, fontsize=12, ha='center', transform=plt.gca().transAxes, color='red')

    regress_values = x * slope + intercept
    
    # Plot scatter plot
    plt.scatter(x, y)

    # Plot regression line
    plt.plot(x, slope*x + intercept, color='red')

    # Add labels and title
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    # print the r value
    print(f'The r-value is: {r_value**2}')
    
    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        haiku-pauwela  20.9219 -156.3051     20.02        76           0
# 2             chul'man  56.8479  124.9104    -15.74        98         100
# 3             sisimiut  66.9395  -53.6735    -22.85        84          28
# 4          olonkinbyen  70.9221   -8.7187     -2.04        88         100
# 6             keflavik  64.0049  -22.5624      1.95        86          75
#
#          Wind Speed Country        Date
# City_ID
# 1              2.57      US  1707744439
# 2              0.56      RU  1707744440
# 3              3.19      GL  1707744441
# 4              8.10      SJ  1707744441
# 6              8.23      IS  1707744442

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]


# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                         bredasdorp -34.5322   20.0403     33.04        30
# 5                          papatowai -46.5619  169.4708     10.72        86
# 7                  port-aux-francais -49.3500   70.2167      6.78        84
# 13       edinburgh of the seven seas -37.0676  -12.3116     17.15        72
# 14                         manokwari  -0.8667  134.0833     26.42        82
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        5.85      ZA  1707744438
# 5                97        1.55      NZ  1707744442
# 7               100       13.74      TF  1707744443
# 13               83        9.29      SH  1707744447
# 14               52        2.75      ID  1707744448

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# Scatter plot for latitude vs. maximum temperature in the Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], alpha=0.5, edgecolors='black')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])

# Plot the regression line
plt.plot(northern_hemi_df['Lat'], intercept + slope * northern_hemi_df['Lat'], 'r', label='fitted line')

# Add the equation of the line to the plot
plt.text(0, northern_hemi_df['Max Temp'].max(), f'y = {slope:.2f}x + {intercept:.2f}', color='red')

plt.grid(True)
plt.title("Northern Hemisphere Max Latitude vs. Temperature")
plt.tight_layout()
plt.legend()

# Show plot
plt.show()

# Print the r-value
print(f'The r-value is: {r_value**2}')
# Out:
# The r-value is: 0.7784664424761893

# %%
# Linear regression on Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Latitude', 'Max Temp')
# Out:
# The r-value is: 0.33327988289895283

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r-value is: 0.22868038529426604

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r-value is: 0.04328303883972886

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness')
# Out:
# The r-value is: 0.004956437284876672

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness')
# Out:
# The r-value is: 0.057412388096777525

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed')
# Out:
# The r-value is: 0.03826055054033499

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed')
# Out:
# The r-value is: 0.06122250124441314

# %% [markdown]
# **Discussion about the linear relationship:**

# %%
#Discussion about the linear relationship:
# The r-value for both hemispheres indicates that there are no linear correlations between latitude and wind speed.
